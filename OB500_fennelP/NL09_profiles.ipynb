# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import datetime as dt
import romspy

freefile = 'Z:/roms/Apps/OB500_fennelP/NL09/ob500_sta.nc'
obsfile = 'F:/okada/Dropbox/Data/ob500_obs_2012_obweb-3.nc'


def profiles(time, station):
    ax = romspy.profiles.fennelP(time, station, freefile=freefile, obsfile=obsfile)
    ax[0][0].set_xlim(0,30)
    ax[0][1].set_xlim(20,35)
    ax[1][0].set_xlim(0,10)
    ax[1][1].set_xlim(0,10)

def profiles_mg(time, station):
    ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
    """ax[0][0].set_xlim(0,30)
    ax[0][1].set_xlim(20,35)
    ax[0][2].set_xlim(0,10)
    ax[0][3].set_xlim(0,10.0)
    ax[1][0].set_xlim(0,0.1)
    ax[1][1].set_xlim(0,1)
    ax[1][2].set_xlim(0,0.01)
    ax[1][3].set_xlim(0,0.01)"""

romspy.get_time(freefile)
# Out:
# get_time(Z:/roms/Apps/OB500_fennelP/NL09/ob500_sta.nc, which=ends, tunit=seconds since 1968-05-23 09:00:00 GMT, name=ocean_time)
# 2012-01-01 00:00:00 0
# 2012-01-18 00:00:00 34

# %%
time = dt.datetime(2012,1,7,0)
profiles_mg(time, 12)
# Out:
# Z:/roms/Apps/OB500_fennelP/NL09/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-01-18 00:00:00
# F:/okada/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00

# %%
time = dt.datetime(2012,6,29,12)
profiles(time, 12)
# Out:
# Z:/roms/Apps/OB500_fennelP/NL08/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-29 12:00:00
# F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc
# 2012-08-01 00:00:00 - 2012-09-01 00:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-eb0fb8fedbf5> in <module>()
#       1 time = dt.datetime(2012,6,29,12)
# ----> 2 profiles(time, 12)
#
# <ipython-input-10-68df20e402e6> in profiles(time, station)
#      10
#      11 def profiles(time, station):
# ---> 12     ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
#      13     ax[0].set_xlim(15,25)
#      14     ax[1].set_xlim(25,32)
#
# f:\WinPython-64bit-2.7.10.2\python-2.7.10.amd64\lib\site-packages\romspy\profiles_mg.pyc in fennelP(dtime, station, freefile, assifile, obsfile, pngfile)
#     157         avar, adepth = read_sta(assifile, dtime, station, varnames)
# ...
