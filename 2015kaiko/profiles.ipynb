# %%
# %matplotlib inline

import datetime as dt
import matplotlib.pyplot as plt

import romspy

tunit = 'seconds since 2012-06-01 00:00:00 GMT'

freefile = '/Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'


def profiles(station, assifile):
    ax = romspy.profiles.npzd(time, station, freefile=freefile, assifile=assifile, obsfile=obsfile, tunit=tunit)
    #ax[0].set_xlim(5,30)
    #ax[2].set_xlim(0,10)
    #ax[3].set_xlim(0,0.1)
    #ax[4].set_xlim(0,0.1)
    #ax[5].set_xlim(0,0.1)
    #ax[6].set_xlim(0,20)

assifile = '/Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_024.nc'
romspy.get_time(assifile, tunit=tunit)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_024.nc
# 2012-08-23 23:50:00 0
# 2012-08-24 00:50:00 6

# %%
time = dt.datetime(2012,8,24,0)

for station in [3, 4, 5, 6, 12, 13]:
    ax = profiles(station, assifile)
    plt.savefig('npzd_sta{}.png'.format(station), bbox_inches='tight', dpi=300)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_024.nc
# 2012-08-23 23:50:00 - 2012-08-24 00:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_024.nc
# 2012-08-23 23:50:00 - 2012-08-24 00:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_024.nc
# ...

# %%
tunit = 'seconds since 2012-06-01 00:00:00 GMT'
assifile = '/Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_012.nc'
romspy.get_time(freefile, tunit=tunit)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 0
# 2012-08-30 00:00:00 2160

# %%
time = dt.datetime(2012,8,23,12)

for station in [3, 4, 5, 6, 12, 13]:
    ax = profiles(station, assifile)
    plt.savefig('npzd_sta{}.png'.format(station), bbox_inches='tight', dpi=300)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_012.nc
# 2012-08-23 11:50:00 - 2012-08-23 12:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_012.nc
# 2012-08-23 11:50:00 - 2012-08-23 12:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_012.nc
# ...

# %%
assifile = '/Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_036.nc'
romspy.get_time(assifile, tunit=tunit)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_036.nc
# 2012-08-24 11:50:00 0
# 2012-08-24 12:50:00 6

# %%
time = dt.datetime(2012,8,24,12)

for station in [3, 4, 5, 12]:
    ax = profiles(station)
# Out:
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_036.nc
# 2012-08-24 11:50:00 - 2012-08-24 12:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_036.nc
# 2012-08-24 11:50:00 - 2012-08-24 12:50:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/non_wq_runk_NL_20120608_5/osaka-bay_sta.nc
# 2012-06-01 00:00:00 - 2012-08-30 00:00:00
# /Users/teruhisa/Dropbox/Data/2015kaiko/fujii/group_4dvar210_2_sta/osaka-bay_sta_036.nc
# ...
