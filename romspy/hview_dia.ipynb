# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import netCDF4

import romspy

ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'
    
def hview(name, interval=None, k=20, cff=1.0, fmt='%i'):
    fig, ax = plt.subplots(1,1,figsize=[7,6])
    ax = romspy.hview(ncfile, name, time, k, mapfile=mapfile, cblabel=name, cff=cff, interval=interval)

romspy.get_time(ncfile, 'all')
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc
# 2012-05-12 12:00:00 0
# 2012-05-19 12:00:00 1
# 2012-05-26 12:00:00 2
# 2012-06-02 12:00:00 3
# 2012-06-09 12:00:00 4
# 2012-06-16 12:00:00 5
# 2012-06-23 12:00:00 6
# 2012-06-30 12:00:00 7
# 2012-07-07 12:00:00 8

# %%
time = dt.datetime(2012, 7, 7, 12)

hview('t_PPmax')
hview('LDIN', np.linspace(0,1,11), cff=7.0)
hview('LPO4', np.linspace(0,1,11), cff=7.0)
hview('P_Production')
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc
# 2012-05-12 12:00:00 - 2012-07-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc
# 2012-05-12 12:00:00 - 2012-07-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc
# 2012-05-12 12:00:00 - 2012-07-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_dia_0003.nc
# 2012-05-12 12:00:00 - 2012-07-07 12:00:00

# %%
time = dt.datetime(2012, 3, 12, 12)

for name in ['t_PPmax','LDIN', 'LPO4', 'P_Production']:
    hview(name)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
