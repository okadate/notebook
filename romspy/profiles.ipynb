# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc'
assifile = '/Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc'


def profiles(station):
    ax = romspy.profiles.fennelP(time, station, freefile=freefile, assifile=assifile, obsfile=obsfile)
    #ax = romspy.profiles.fennelP(time, station, freefile=freefile, assifile=assifile, obsfile=obsfile)
    ax[0].set_xlim(20,30)
    ax[1].set_xlim(20,33)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,10)
    ax[4].set_xlim(0,10)
    #ax[5].set_xlim(0,1.0)
    #ax[6].set_xlim(0,1.0)
    #ax[7].set_xlim(0,500)

romspy.get_time(assifile, 'all')
# Out:
# /Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc
# 2012-08-06 00:00:00 0
# 2012-08-06 02:00:00 1
# 2012-08-06 00:00:00 2
# 2012-08-06 02:00:00 3

# %%
time = dt.datetime(2012,8,6,0)

for station in [3,4,5,12]:
    profiles(station)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# /Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# /Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# /Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# /Users/teruhisa/mnt/data/is4dvar_out/03/ob500_sta_24.nc
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
