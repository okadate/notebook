# %%
# %matplotlib inline

import datetime as dt

import romspy

time = dt.datetime
free = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/ob500_sta.nc'
obs = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-1.nc'
#png = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/profiles_{}_{}.png'

ax = romspy.profiles.fennelP(time(2012,2,1,0), 5, free=free, obs=obs)
ax[0].set_xlim(5,20)
#ax[1].set_xlim(25,35)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/ob500_sta.nc
# 2012-01-01 00:00:00 0
# 2012-02-01 00:00:00 62
# 2012-10-01 12:00:00 550
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-1.nc
# 2012-01-01 00:00:00 0
# 2012-02-01 00:00:00 383007.0
# 2013-01-01 23:00:00 3488698
# (5, 20)

# %%
romspy.profiles.fennelP(t(2012,8,1,0), 12, free=free, obs=obs)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/ob500_sta.nc
# 2012-01-01 00:00:00 0
# 2012-08-01 00:00:00 426
# 2012-10-01 12:00:00 550
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-1.nc
# 2012-01-01 00:00:00 0
# 2012-08-01 00:00:00 387375.0
# 2013-01-01 23:00:00 3488698
