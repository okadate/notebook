# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

import romspy


time = dt.datetime(2012, 3, 5, 12)
ncfile = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_dia_0003.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'SOD', time, interval=np.arange(-30,1,5), mapfile=mapfile)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_dia_0003.nc
# 2012-03-01 12:00:00 - 2012-03-30 12:00:00

# %%
ncfile = '/Users/teruhisa/Dropbox/Data/ob500_grd-8.nc'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'h', mapfile=mapfile, cmap='ocean', cff=-1, interval=np.arange(-100,1,20))
# Out:
# /Users/teruhisa/Dropbox/Data/ob500_grd-8.nc
