# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = '/Users/teruhisa/mnt/hydcl00/OB500/Biology_test_0/test_boundary/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'


def profiles(station):
    ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
    ax[0].set_xlim(5,30)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,0.1)
    ax[4].set_xlim(0,0.1)
    ax[5].set_xlim(0,0.1)
    ax[6].set_xlim(0,20)

romspy.get_time(freefile)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-a398ca2492e5> in <module>()
#      18     ax[6].set_xlim(0,20)
#      19
# ---> 20 romspy.get_time(freefile)
#
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/romspy/get_time.pyc in get_time(ncfile, which)
#      10 def get_time(ncfile, which='ends'):
#      11     JST = 'seconds since 1968-05-23 09:00:00 GMT'
# ---> 12     nc = netCDF4.Dataset(ncfile, 'r')
#      13     time = nc.variables['ocean_time'][:]
#      14     print ncfile
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__ (netCDF4/_netCDF4.c:9551)()
#
# RuntimeError: No such file or directory

# %%
time = dt.datetime(2012,2,20,0)

for station in [3,4,5,12]:
    profiles(station)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-20 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-20 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-20 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-20 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1974: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
