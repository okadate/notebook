# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import netCDF4

import romspy

ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'
    
def hview(name):
    fig, ax = plt.subplots(1,1,figsize=[7,6])
    if 'L' in name:
        interval=np.linspace(0,1,10)
        cff=7.0
    elif name == 't_PPmax':
        interval=None
        cff=7.0
    else:
        interval=None
        cff=1.0
    ax = romspy.hview(ncfile, name, time, 20, mapfile=mapfile, cblabel=name, cff=cff, interval=interval)

romspy.get_time(ncfile)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 0
# 2012-05-07 12:00:00 8

# %%
time = dt.datetime(2012, 7, 19, 12)

for name in ['t_PPmax','LDIN', 'LPO4', 'P_Production']:
    hview(name)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0004.nc
# 2012-07-12 12:00:00 - 2012-07-19 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0004.nc
# 2012-07-12 12:00:00 - 2012-07-19 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0004.nc
# 2012-07-12 12:00:00 - 2012-07-19 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0004.nc
# 2012-07-12 12:00:00 - 2012-07-19 12:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':

# %%
time = dt.datetime(2012, 3, 12, 12)

for name in ['t_PPmax','LDIN', 'LPO4', 'P_Production']:
    hview(name)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_dia_0002.nc
# 2012-03-12 12:00:00 - 2012-05-07 12:00:00
