# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

import romspy

ncfile = '/Users/teruhisa/Dropbox/Data/ob500_grd-8.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'h', mapfile=mapfile, cmap='ocean', cff=-1, interval=np.arange(-100,1,10))
plt.savefig('/Users/teruhisa/Dropbox/Data/ob500_grd-8.png', bbox_inches='tight', dpi=300)
# Out:
# /Users/teruhisa/Dropbox/Data/ob500_grd-8.nc
