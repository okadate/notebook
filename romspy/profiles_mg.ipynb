# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc'

romspy.get_time(freefile)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc
# 2012-01-01 00:00:00 0
# 2013-01-01 00:00:00 732

# %%
time = dt.datetime(2012,8,1,0)

for station in [3,4,5,12]:
    ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc
# 2012-01-01 00:00:00 - 2013-01-01 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc
# 2012-01-01 00:00:00 - 2013-01-01 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc
# 2012-01-01 00:00:00 - 2013-01-01 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc
# 2012-01-01 00:00:00 - 2013-01-01 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00

# %%
freefile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL07/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc'
time = dt.datetime(2012,7,23,12)

for station in [3,4,5,12]:
    ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-07-23 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-07-23 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-07-23 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-07-23 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1974: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
time = dt.datetime(2012,7,23,12)

for station in [3,4,5,12]:
    profiles(station)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-30 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-30 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-30 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-30 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
