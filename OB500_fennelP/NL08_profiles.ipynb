# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = 'Z:/roms/Apps/OB500_fennelP/NL08/ob500_sta.nc'
obsfile = 'F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc'


def profiles(time, station):
    ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
    ax[0].set_xlim(15,25)
    ax[1].set_xlim(25,32)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,0.5)
    ax[4].set_xlim(0,0.5)
    ax[5].set_xlim(0,0.05)
    ax[6].set_xlim(0,0.05)

romspy.get_time(freefile)
# Out:
# get_time(Z:/roms/Apps/OB500_fennelP/NL08/ob500_sta.nc, which=ends, tunit=seconds since 1968-05-23 09:00:00 GMT, name=ocean_time)
# 2012-01-01 00:00:00 0
# 2012-09-29 00:00:00 544

# %%
romspy.get_variables(obsfile)
# Out:
# F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc
# [u'spherical', u'Nobs', u'survey_time', u'obs_variance', u'obs_type', u'obs_provenance', u'obs_station', u'obs_time', u'obs_depth', u'obs_Xgrid', u'obs_Ygrid', u'obs_Zgrid', u'obs_lon', u'obs_lat', u'obs_error', u'obs_value']

# %%
romspy.get_time(obsfile, name='*time')
# Out:
# get_time(F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc, which=ends, tunit=seconds since 1968-05-23 09:00:00 GMT, name=*time)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-403b245eccff> in <module>()
# ----> 1 romspy.get_time(obsfile, name='*time')
#
# f:\WinPython-64bit-2.7.10.2\python-2.7.10.amd64\lib\site-packages\romspy\get_time.pyc in get_time(ncfile, which, tunit, name)
#      14     nc = netCDF4.Dataset(ncfile, 'r')
#      15     if which == 'ends':
# ---> 16         t = len(nc.dimensions[name])
#      17         start = nc.variables[name][0]
#      18         end = nc.variables[name][t-1]
#
# KeyError: '*time'

# %%
time = dt.datetime(2012,8,1,0)
profiles(time, 3)
# Out:
# Z:/roms/Apps/OB500_fennelP/NL08/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-29 00:00:00
# F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc
# 2012-08-01 00:00:00 - 2012-09-01 00:00:00

# %%
time = dt.datetime(2012,6,29,12)
profiles(time, 12)
# Out:
# Z:/roms/Apps/OB500_fennelP/NL08/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-09-29 12:00:00
# F:/okada/Dropbox/Data/ob500_obs_201208_obweb-3.nc
# 2012-08-01 00:00:00 - 2012-09-01 00:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-eb0fb8fedbf5> in <module>()
#       1 time = dt.datetime(2012,6,29,12)
# ----> 2 profiles(time, 12)
#
# <ipython-input-10-68df20e402e6> in profiles(time, station)
#      10
#      11 def profiles(time, station):
# ---> 12     ax = romspy.profiles_mg.fennelP(time, station, freefile=freefile, obsfile=obsfile)
#      13     ax[0].set_xlim(15,25)
#      14     ax[1].set_xlim(25,32)
#
# f:\WinPython-64bit-2.7.10.2\python-2.7.10.amd64\lib\site-packages\romspy\profiles_mg.pyc in fennelP(dtime, station, freefile, assifile, obsfile, pngfile)
#     157         avar, adepth = read_sta(assifile, dtime, station, varnames)
# ...
