# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

import romspy

#time = dt.datetime(2012, 6, 7, 11)
#ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL03/ob500_dia_0006.nc'

# %%
time = dt.datetime(2012, 1, 9, 0)
ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_rst.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'LdetritusN', time, 20, mapfile=mapfile)#, interval=np.arange(0,0.1,10))
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_rst.nc
# 2012-01-08 00:00:00 - 2012-01-09 00:00:00

# %%
time = dt.datetime(2012, 6, 17, 0)
ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL03/ob500_his_0003.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'chlorophyll', time, 20, mapfile=mapfile)#, interval=np.arange(0.0,0.01,0.001))
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL03/ob500_his_0003.nc
# 2012-05-13 00:00:00 - 2012-07-08 00:00:00

# %%
ncfile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_his_0003.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'
time = dt.datetime(2012, 6, 17, 0)

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'chlorophyll', time, 20, mapfile=mapfile)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_his_0003.nc
# 2012-05-13 00:00:00 - 2012-06-17 00:00:00

# %%
time = dt.datetime(2012, 1, 1, 0)
ncfile = '/Users/teruhisa/Dropbox/Data/ob500_ini_fennelP-6.nc'
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'LdetritusN', time, 20, mapfile=mapfile)#, interval=np.arange(0,0.1,10))
# Out:
# /Users/teruhisa/Dropbox/Data/ob500_ini_fennelP-6.nc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a9d16cf93af2> in <module>()
#       4
#       5 fig, ax = plt.subplots(1,1,figsize=[7,6])
# ----> 6 ax = romspy.hview(ncfile, 'LdetritusN', time, 20, mapfile=mapfile)#, interval=np.arange(0,0.1,10))
#
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/romspy/hview.pyc in hview(ncfile, vname, time, k, interval, fmt, cff, cblabel, mapfile, cmap, figfile)
#      25     print ncfile
#      26
# ---> 27     x_rho = nc.variables['lon_rho'][0,:]-0.00449/2
#      28     y_rho = nc.variables['lat_rho'][:,0]-0.00546/2
#      29
#
# KeyError: 'lon_rho'

# %%
ncfile = '/Users/teruhisa/Dropbox/Data/ob500_grd-8.nc'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'h', mapfile=mapfile, cmap='ocean', cff=-1, interval=np.arange(-100,1,20))
# Out:
# /Users/teruhisa/Dropbox/Data/ob500_grd-8.nc
