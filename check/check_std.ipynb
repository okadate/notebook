# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import romspy

#stdfile = '/Users/teruhisa/Dropbox/Data/ob500a_std_i_NL05_his_0004.nc'
stdfile = '/Users/teruhisa/Dropbox/Data/ob500a_std_i_fennelP-2.nc'

romspy.get_time(stdfile)
# Out:
# /Users/teruhisa/Dropbox/Data/ob500a_std_i_fennelP-2.nc
# 2012-01-01 00:00:00 0
# 2012-01-01 00:00:00 0

# %%
import datetime
import numpy as np

time = datetime.datetime(2012,1,1,0)
mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

romspy.hview(stdfile, 'chlorophyll', time, 20, interval=np.arange(0,3.1,1), mapfile=mapfile)
# Out:
# chlorophyll /Users/teruhisa/Dropbox/Data/ob500a_std_i_fennelP-2.nc
