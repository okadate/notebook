# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'


def profiles(station):
    ax = romspy.profiles.fennelP(time, station, freefile=freefile, obsfile=obsfile)
    ax[0].set_xlim(10,25)
    ax[1].set_xlim(20,33)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,10)
    ax[4].set_xlim(0,10)
    #ax[5].set_xlim(0,1.0)
    #ax[6].set_xlim(0,1.0)
    #ax[7].set_xlim(0,500)

romspy.get_time(freefile, 'ends')
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# 2012-01-01 00:00:00 0
# 2012-08-01 12:00:00 427

# %%
time = dt.datetime(2012,8,1,0)

for station in [3,4,5,12]:
    profiles(station)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-08-01 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-08-01 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-08-01 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL05/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-08-01 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1974: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
