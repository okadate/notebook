# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import datetime
import numpy as np
import netCDF4

import romspy

date = datetime.datetime(2012, 8, 5, 0)
ncfile = '/home/okada/roms/Apps/OB500_fennelP/4DVAR04/output/ob500_ini_0.nc'
mapfile = '/home/okada/Dropbox/Data/deg_OsakaBayMap_okada.bln'
obsfile = '/home/okada/Dropbox/Data/ob500_obs_201208_bio-1.nc'

romspy.get_time(ncfile)
# Out:
# /home/okada/roms/Apps/OB500_fennelP/4DVAR04/output/ob500_ini_0.nc
# 2012-08-05 00:00:00 0
# 2012-08-05 00:00:00 1

# %%
romspy.hview(ncfile, 'oxygen', date, 1, interval=np.arange(0,200.1,50), mapfile=mapfile)
romspy.hplot_values(obsfile, 15, date, vmin=0, vmax=200)
#plt.savefig("hview_test.png")
# Out:
# oxygen /home/okada/roms/Apps/OB500_fennelP/4DVAR04/output/ob500_ini_0.nc
# 2012-08-01 00:00:00 - 2012-09-01 00:00:00
# /home/okada/anaconda/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /home/okada/anaconda/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':

# %%
romspy.hplot_values(obsfile, 15, date, vmin=0, vmax=200)
# Out:
# 2012-08-01 00:00:00 - 2012-09-01 00:00:00
