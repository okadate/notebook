# %%
# %matplotlib inline

import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

import romspy

mapfile = '/Users/teruhisa/Dropbox/Data/deg_OsakaBayMap_okada.bln'

ncfile = '/Users/teruhisa/mnt/hydcl00/OB500/Data/ob500_grd-v5.nc'

fig, ax = plt.subplots(1,1,figsize=[7,6])
ax = romspy.hview(ncfile, 'h', mapfile=mapfile, cmap='ocean', cff=-1, interval=np.arange(-100,1,20))
romspy.hplot_stations("/Users/teruhisa/Dropbox/Data/stations6.csv")
# Out:
# /Users/teruhisa/mnt/hydcl00/OB500/Data/ob500_grd-v5.nc
#    station        lat         lon
# 0        3  34.431667  135.197778
# 1        4  34.647222  135.276667
# 2        5  34.661389  135.367222
# 3        6  34.460556  135.326389
# 4       12  34.611667  135.378889
# 5       13  34.495000  135.345278
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':
