# %%
% matplotlib inline

import numpy as np
import matplotlib.pyplot as plt


def plotR(theta=1.05):
    temp = np.arange(5.0, 35.1, 1)
    R = theta ** (temp - 20.0)
    plt.plot(temp, R, 'ko-')
    
plotR(1.05)

# %%
plotR(1.05)
plotR(1.08)
plotR(1.1)
