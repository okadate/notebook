# %%
# %matplotlib inline

import datetime as dt

import romspy

time = dt.datetime(2012,1,10,0)
freefile = '/Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'

ax = romspy.profiles_mg.fennelP(time, 12, freefile=freefile, obsfile=obsfile)
def lims(ax):
    ax[0].set_xlim(5,30)
    ax[2].set_xlim(0,10)
    ax[3].set_xlim(0,0.1)
    ax[4].set_xlim(0,0.1)
    ax[5].set_xlim(0,0.1)
    ax[6].set_xlim(0,20)
lims(ax)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-01-10 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1974: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
ax = romspy.profiles_mg.fennelP(time, 3, freefile=freefile, obsfile=obsfile)
lims(ax)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-71b8b2cbafe5> in <module>()
# ----> 1 ax = romspy.profiles_mg.fennelP(time, 3, freefile=freefile, obsfile=obsfile)
#       2 lims(ax)
#
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/romspy/profiles_mg.pyc in fennelP(dtime, station, freefile, assifile, obsfile, pngfile)
#     134
#     135     if freefile is not None:
# --> 136         fvar, fdepth = read_sta(freefile, dtime, station, varnames)
#     137     if assifile is not None:
#     138         avar, adepth = read_sta(assifile, dtime, station, varnames)
#
# /Users/teruhisa/anaconda/lib/python2.7/site-packages/romspy/profiles_mg.pyc in read_sta(stafile, dtime, station, varnames)
#      31 def read_sta(stafile, dtime, station, varnames):
#      32
# ---> 33     nc = netCDF4.Dataset(stafile, 'r')
# ...

# %%
ax = romspy.profiles_mg.fennelP(time, 4, freefile=freefile, obsfile=obsfile)
lims(ax)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-06-22 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00

# %%
ax = romspy.profiles_mg.fennelP(time, 5, freefile=freefile, obsfile=obsfile)
lims(ax)
# Out:
# /Users/teruhisa/mnt/apps/OB500_fennelP/NL04/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-06-22 00:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
