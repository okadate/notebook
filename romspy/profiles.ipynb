# %%
# %matplotlib inline

import datetime as dt

import romspy

time = dt.datetime
free = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_sta.nc'
obs = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'
#png = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/profiles_{}_{}.png'

time = dt.datetime(2012,2,1,0)
ax = romspy.profiles.fennelP(time, 3, free=free, obs=obs)
ax[0].set_xlim(5,20)
#ax[1].set_xlim(25,35)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-13 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# (5, 20)

# %%
ax = romspy.profiles.fennelP(time, 12, free=free, obs=obs)
ax[0].set_xlim(5,20)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-13 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# (5, 20)

# %%
ax = romspy.profiles.fennelP(time, 5, free=free, obs=obs)
ax[0].set_xlim(5,20)
# Out:
# /Users/teruhisa/Dropbox/Data/OB500_fennelP/NL02/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-02-13 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# (5, 20)
