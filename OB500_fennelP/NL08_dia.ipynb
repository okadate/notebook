# %%
# %matplotlib inline

import numpy as np
import romspy

ncfile = 'Z:/roms/Apps/OB500_fennelP/NL08/ob500_dia.nc'
mapfile = 'F:/okada/Dropbox/Data/deg_OsakaBayMap_okada.bln'

dia = romspy.hview.Dataset(ncfile, mapfile=mapfile)
dia.print_time('all')
dia.print_varname(ndim=4)
# Out:
# Dataset(ncfile=Z:/roms/Apps/OB500_fennelP/NL08/ob500_dia.nc)
#
# print_time(which=all, name=ocean_time, tunit=seconds since 1968-05-23 09:00:00 GMT)
# 2012-01-04 12:00:00 0
# 2012-01-11 12:00:00 1
# 2012-01-18 12:00:00 2
# 2012-01-25 12:00:00 3
# 2012-02-01 12:00:00 4
# 2012-02-08 12:00:00 5
# 2012-02-15 12:00:00 6
# 2012-02-22 12:00:00 7
# 2012-02-29 12:00:00 8
# 2012-03-07 12:00:00 9
# 2012-03-14 12:00:00 10
# 2012-03-21 12:00:00 11
# 2012-03-28 12:00:00 12
# 2012-04-04 12:00:00 13
# 2012-04-11 12:00:00 14
# 2012-04-18 12:00:00 15
# 2012-04-25 12:00:00 16
# 2012-05-02 12:00:00 17
# 2012-05-09 12:00:00 18
# 2012-05-16 12:00:00 19
# 2012-05-23 12:00:00 20
# 2012-05-30 12:00:00 21
# 2012-06-06 12:00:00 22
# 2012-06-13 12:00:00 23
# 2012-06-20 12:00:00 24
# 2012-06-27 12:00:00 25
# 2012-07-04 12:00:00 26
# 2012-07-11 12:00:00 27
# 2012-07-18 12:00:00 28
# 2012-07-25 12:00:00 29
# 2012-08-01 12:00:00 30
# 2012-08-08 12:00:00 31
# 2012-08-15 12:00:00 32
# 2012-08-22 12:00:00 33
# ...

# %%
dia.hview('LPO4', time=30, k=20, cff=7.0, interval=np.arange(0.0,1.1,0.2), fmt='%.1f')
# Out:
# hview(vname=LPO4, time=30, k=20, interval=[ 0.   0.2  0.4  0.6  0.8  1. ], fmt=%.1f, cff=7.0, cblabel=None, cmap=jet, grdfile=None, tunit=seconds since 1968-05-23 09:00:00 GMT)

# %%
dia.hview('PO4', time=7, k=1, interval=np.arange(0.0,0.5,0.1), fmt='%.1f')
# Out:
# hview() PO4 7 1 [ 0.   0.1  0.2  0.3  0.4] %.1f 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT

# %%
dia.hview('phytoplankton', time=7, k=1, interval=np.arange(0.0,5.1,1.0))
# Out:
# hview() phytoplankton 7 1 [ 0.  1.  2.  3.  4.  5.] %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT

# %%
dia.hview('chlorophyll', time=7, k=1, interval=np.arange(0.0,5.1,1.0))
# Out:
# hview() chlorophyll 7 1 [ 0.  1.  2.  3.  4.  5.] %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
