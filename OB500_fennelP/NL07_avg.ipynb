# %%
# %matplotlib inline

import numpy as np
import romspy

ncfile = 'Z:/roms/Apps/OB500_fennelP/NL07/ob500_avg.nc'
mapfile = 'F:/okada/Dropbox/Data/deg_OsakaBayMap_okada.bln'

dia = romspy.hview.Dataset(ncfile, mapfile=mapfile)
dia.print_time('all')
dia.print_varname(ndim=4)
# Out:
# Dataset(ncfile=Z:/roms/Apps/OB500_fennelP/NL07/ob500_avg.nc)
#
# print_time(which=all, name=ocean_time, tunit=seconds since 1968-05-23 09:00:00 GMT)
# 2012-01-16 06:00:00
#  0
# 2012-02-15 18:00:00 1
# 2012-03-17 06:00:00 2
# 2012-04-16 18:00:00 3
# 2012-05-17 06:00:00 4
# 2012-06-16 18:00:00 5
# 2012-07-17 06:00:00 6
# 2012-08-16 18:00:00 7
# 2012-09-16 06:00:00 8
# 2012-10-16 18:00:00 9
# 2012-11-16 06:00:00 10
# 2012-12-16 18:00:00 11
#
# print_varname(ndim=4)
# u v u_eastward v_northward w temp salt NO3 NH4 chlorophyll phytoplankton zooplankton LdetritusN SdetritusN oxygen PO4 LdetritusP SdetritusP rho AKv

# %%
for vname in dia.get_varname(ndim=4):
    if vname not in ['u', 'v']:
        dia.hview(vname, time=7, k=1)#, interval=np.arange(-100.0,0.1,50))
        dia.show()
        #dia.savefig('{}_{}_{}.png'.format(ncfile[:-3], vname, 1))
# Out:
# hview() u_eastward 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() v_northward 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() w 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() temp 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() salt 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() NO3 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() NH4 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() chlorophyll 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() phytoplankton 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() zooplankton 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() LdetritusN 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() SdetritusN 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() oxygen 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() PO4 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() LdetritusP 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() SdetritusP 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() rho 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# hview() AKv 7 1 None %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7d3ad1be608d> in <module>()
#       1 for vname in dia.get_varname(ndim=4):
#       2     if vname not in ['u', 'v']:
# ----> 3         dia.hview(vname, time=7, k=1)#, interval=np.arange(-100.0,0.1,50))
#       4         dia.show()
#       5         #dia.savefig('{}_{}_{}.png'.format(ncfile[:-3], vname, 1))
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\romspy\hview.pyc in hview(self, vname, time, k, interval, fmt, cff, cblabel, cmap, grdfile, tunit)
#     112             CF = plt.contour(X+0.00449, Y+0.00546, var2d, interval, colors='k', ls='-')
#     113         else:
# --> 114             CF = plt.contour(X+0.00449, Y+0.00546, var2d, colors='k', ls='-')
#     115         CF.clabel(fontsize=9, fmt=fmt, c='k')
#     116
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\pyplot.pyc in contour(*args, **kwargs)
#    2630         ax.hold(hold)
#    2631     try:
# -> 2632         ret = ax.contour(*args, **kwargs)
#    2633         draw_if_interactive()
#    2634     finally:
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\axes.pyc in contour(self, *args, **kwargs)
#    7974             self.cla()
#    7975         kwargs['filled'] = False
# -> 7976         return mcontour.QuadContourSet(self, *args, **kwargs)
#    7977     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    7978
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\contour.pyc in __init__(self, ax, *args, **kwargs)
#    1412         are described in QuadContourSet.contour_doc.
#    1413         """
# -> 1414         ContourSet.__init__(self, ax, *args, **kwargs)
#    1415
#    1416     def _process_args(self, *args, **kwargs):
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\contour.pyc in __init__(self, ax, *args, **kwargs)
#     859
#     860         self._process_args(*args, **kwargs)
# --> 861         self._process_levels()
#     862
#     863         if self.colors is not None:
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\contour.pyc in _process_levels(self)
#    1190         # The following attributes are no longer needed, and
#    1191         # should be deprecated and removed to reduce confusion.
# -> 1192         self.vmin = np.amin(self.levels)
#    1193         self.vmax = np.amax(self.levels)
#    1194
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\numpy\core\fromnumeric.pyc in amin(a, axis, out, keepdims)
#    2212     else:
#    2213         return _methods._amin(a, axis=axis,
# -> 2214                             out=out, keepdims=keepdims)
#    2215
#    2216 def alen(a):
#
# F:\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\numpy\core\_methods.pyc in _amin(a, axis, out, keepdims)
#      19 def _amin(a, axis=None, out=None, keepdims=False):
#      20     return um.minimum.reduce(a, axis=axis,
# ---> 21                             out=out, keepdims=keepdims)
#      22
#      23 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
dia.hview('PO4', time=7, k=1, interval=np.arange(0.0,0.5,0.1), fmt='%.1f')
# Out:
# hview() PO4 7 1 [ 0.   0.1  0.2  0.3  0.4] %.1f 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT

# %%
dia.hview('phytoplankton', time=7, k=1, interval=np.arange(0.0,5.1,1.0))
# Out:
# hview() phytoplankton 7 1 [ 0.  1.  2.  3.  4.  5.] %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT

# %%
dia.hview('chlorophyll', time=7, k=1, interval=np.arange(0.0,5.1,1.0))
# Out:
# hview() chlorophyll 7 1 [ 0.  1.  2.  3.  4.  5.] %i 1.0 None jet None seconds since 1968-05-23 09:00:00 GMT
