# %%
# %matplotlib inline

import datetime as dt

import romspy

time = dt.datetime(2012,1,11,0)
#freefile = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL03/ob500_sta.nc'
freefile = '/Users/teruhisa/mnt/hydcl00/NL03/ob500_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc'
#pngfile = '/Users/teruhisa/Dropbox/Data/OB500_fennelP/NL/profiles_{}_{}.png'

ax = romspy.profiles_mg.fennelP(time, 12, freefile=freefile, obsfile=obsfile)
def lims(ax):
    ax[0].set_xlim(5,25)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,0.1)
    ax[4].set_xlim(0,1)
    ax[5].set_xlim(0,1)
#lims(ax)
# Out:
# /Users/teruhisa/mnt/hydcl00/NL03/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-01-11 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00

# %%
ax = romspy.profiles.fennelP(time, 3, freefile=freefile, obsfile=obsfile)
lims(ax)
# Out:
# /Users/teruhisa/mnt/hydcl00/NL03/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-01-05 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00

# %%
ax = romspy.profiles.fennelP(time, 5, freefile=freefile, obsfile=obsfile)
lims(ax)
# Out:
# /Users/teruhisa/mnt/hydcl00/NL03/ob500_sta.nc
# 2012-01-01 00:00:00 - 2012-01-05 12:00:00
# /Users/teruhisa/Dropbox/Data/ob500_obs_2012_obweb-2.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
