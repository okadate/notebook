# %%
# %matplotlib inline

import datetime as dt

import romspy

freefile = '/Users/teruhisa/mnt/apps/OB500A/NL05/ob500a_sta.nc'
assifile = '/Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc'
obsfile = '/Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc'


def profiles(station):
    ax = romspy.profiles.fennelP(time, station, freefile=freefile, assifile=assifile, obsfile=obsfile)
    ax[0].set_xlim(20,30)
    ax[1].set_xlim(20,33)
    ax[2].set_xlim(0,20)
    ax[3].set_xlim(0,10)
    ax[4].set_xlim(0,10)
    #ax[5].set_xlim(0,1.0)
    #ax[6].set_xlim(0,1.0)
    #ax[7].set_xlim(0,500)

romspy.get_time(assifile, 'all')
# Out:
# /Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc
# 2012-08-05 00:00:00 0
# 2012-08-05 01:00:00 1
# 2012-08-05 02:00:00 2
# 2012-08-05 03:00:00 3
# 2012-08-05 04:00:00 4
# 2012-08-05 05:00:00 5
# 2012-08-05 06:00:00 6

# %%
time = dt.datetime(2012,8,5,0)

for station in [3,4,5,12]:
    profiles(station)
# Out:
# /Users/teruhisa/mnt/apps/OB500A/NL05/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-12 00:00:00
# /Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-05 06:00:00
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500A/NL05/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-12 00:00:00
# /Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-05 06:00:00
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500A/NL05/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-12 00:00:00
# /Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-05 06:00:00
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
# /Users/teruhisa/mnt/apps/OB500A/NL05/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-12 00:00:00
# /Users/teruhisa/mnt/apps/OB500A/I4DVAR01/ob500a_sta.nc
# 2012-08-05 00:00:00 - 2012-08-05 06:00:00
# /Users/teruhisa/Dropbox/Data/ob500a_obs_2012_obweb-3.nc
# 2012-01-01 00:00:00 - 2013-01-01 23:00:00
